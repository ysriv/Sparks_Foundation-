# %% [markdown]
# #### Perform ‘Exploratory Data Analysis’ on the provided dataset

# %%
import random
import seaborn
import plotly as py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
import plotly.graph_objs as go

# %%
def get_data():
    data_frame=pd.read_csv("/SampleSuperstore.csv")
    return data_frame

# %% [markdown]
# #### Exploloring our Dataset

# %%
data_frame=get_data()
#Head of Dataset
data_frame.head()
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
#
# [5 rows x 13 columns]

# %%
#getting the information about the Dataframe
print("\nThe Shape of the Dataset : ",data_frame.shape)
print("\nThe No. of entries in the Dataset : ",data_frame.shape[0])
print("\nThe No. of features in the Dataset : ",data_frame.shape[1])
# Out:
# The Shape of the Dataset :  (9994, 13)
#
# The No. of entries in the Dataset :  9994
#
# The No. of features in the Dataset :  13

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data_frame.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
data_frame.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
def Features_wise_Description_and_Frequency(data_set):
    for feature in data_set.columns:
        print("\n\n STATISTIC FOR FEATURE : ",feature.upper())
        print("\nDescription for Feature : \n",)
        print(data_set[feature].describe())
        print("\n")

# %%
Features_wise_Description_and_Frequency(data_frame)
# Out:
#  STATISTIC FOR FEATURE :  SHIP MODE
#
# Description for Feature :
#
# count               9994
# unique                 4
# top       Standard Class
# freq                5968
# Name: Ship Mode, dtype: object
#
#
#
#
#  STATISTIC FOR FEATURE :  SEGMENT
#
# Description for Feature :
#
# count         9994
# unique           3
# top       Consumer
# freq          5191
# Name: Segment, dtype: object
#
#
#
#
#  STATISTIC FOR FEATURE :  COUNTRY
#
# Description for Feature :
#
# count              9994
# unique                1
# top       United States
# freq               9994
# Name: Country, dtype: object
#
#
#
#
#  STATISTIC FOR FEATURE :  CITY
#
# Description for Feature :
#
# count              9994
# unique              531
# top       New York City
# freq                915
# Name: City, dtype: object
#
#
#
#
#  STATISTIC FOR FEATURE :  STATE
#
# Description for Feature :
#
# count           9994
# unique            49
# top       California
# freq            2001
# Name: State, dtype: object
#
#
#
#
#  STATISTIC FOR FEATURE :  POSTAL CODE
#
# Description for Feature :
#
# count     9994.000000
# mean     55190.379428
# std      32063.693350
# min       1040.000000
# 25%      23223.000000
# 50%      56430.500000
# 75%      90008.000000
# max      99301.000000
# Name: Postal Code, dtype: float64
#
#
#
#
#  STATISTIC FOR FEATURE :  REGION
#
# Description for Feature :
#
# count     9994
# unique       4
# top       West
# freq      3203
# Name: Region, dtype: object
#
#
#
#
#  STATISTIC FOR FEATURE :  CATEGORY
#
# Description for Feature :
#
# count                9994
# unique                  3
# top       Office Supplies
# freq                 6026
# Name: Category, dtype: object
#
#
#
#
#  STATISTIC FOR FEATURE :  SUB-CATEGORY
#
# Description for Feature :
#
# count        9994
# unique         17
# top       Binders
# freq         1523
# Name: Sub-Category, dtype: object
#
#
#
#
#  STATISTIC FOR FEATURE :  SALES
#
# Description for Feature :
#
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Sales, dtype: float64
#
#
#
#
#  STATISTIC FOR FEATURE :  QUANTITY
#
# Description for Feature :
#
# count    9994.000000
# mean        3.789574
# std         2.225110
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         5.000000
# max        14.000000
# Name: Quantity, dtype: float64
#
#
#
#
#  STATISTIC FOR FEATURE :  DISCOUNT
#
# Description for Feature :
#
# count    9994.000000
# mean        0.156203
# std         0.206452
# min         0.000000
# 25%         0.000000
# 50%         0.200000
# 75%         0.200000
# max         0.800000
# Name: Discount, dtype: float64
#
#
#
#
#  STATISTIC FOR FEATURE :  PROFIT
#
# Description for Feature :
#
# count    9994.000000
# mean       28.656896
# std       234.260108
# min     -6599.978000
# 25%         1.728750
# 50%         8.666500
# 75%        29.364000
# max      8399.976000
# Name: Profit, dtype: float64

# %% [markdown]
# #### Looking For Redundant/Duplicate and Null entries and Removing them

# %%
def CountAndRemoveDuplicates(data_frame):
    #C;ount Using pivot_table() functio
    print("\n\nThe no. of rows having duplicate values : ",duplicates_df.shape[0])
    
    print("\n\nThe shape of the data_set before removing the duplicates : ",data_frame.shape)
    data_frame = data_frame.drop_duplicates()
    print("\n\nThe shape of the data_set after removing the duplicates : ",data_frame.shape)
    return data_frame

# %%
print("\n\nThe duplicate entries in dataset  :\n")
duplicates_df = data_frame[data_frame.duplicated()]
duplicates_df
# Out:
# The duplicate entries in dataset  :
#            Ship Mode      Segment        Country  ... Quantity Discount   Profit
# 950   Standard Class  Home Office  United States  ...        3      0.2   5.4432
# 3406  Standard Class  Home Office  United States  ...        2      0.3 -12.0588
# 3670  Standard Class     Consumer  United States  ...        2      0.2   3.6288
# 4117  Standard Class     Consumer  United States  ...        3      0.0   9.3312
# 4553  Standard Class     Consumer  United States  ...        3      0.0   5.7780
# 5905        Same Day  Home Office  United States  ...        4      0.0  19.8720
# 6146  Standard Class    Corporate  United States  ...        4      0.0   3.1752
# 6334  Standard Class     Consumer  United States  ...        4      0.0  23.0864
# 6357  Standard Class    Corporate  United States  ...        4      0.0  12.4416
# 7608  Standard Class     Consumer  United States  ...        4      0.0  12.4416
# 7735  Standard Class    Corporate  United States  ...        3      0.0   9.3312
# 7759  Standard Class    Corporate  United States  ...        3      0.2   5.4432
# 8032     First Class     Consumer  United States  ...        3      0.2  16.1838
# 8095    Second Class     Consumer  United States  ...        2      0.0   6.2208
# 9262  Standard Class     Consumer  United States  ...        3      0.0  35.0973
# 9363  Standard Class  Home Office  United States  ...        3      0.0   6.4206
# 9477    Second Class    Corporate  United States  ...        3      0.8  -6.2370
#
# [17 rows x 13 columns]

# %%
data_frame=CountAndRemoveDuplicates(data_frame)
# Out:
# The no. of rows having duplicate values :  17
#
#
# The shape of the data_set before removing the duplicates :  (9994, 13)
#
#
# The shape of the data_set after removing the duplicates :  (9977, 13)

# %%
def CountAndRemoveNullValues(data_frame):
    print("\n\nThe shape of the data_set before removing the null_values : ",data_frame.shape)
    initial=data_frame.shape[0]
    data_frame = data_frame.dropna()
    print("\n\nThe no. of rows having Null values :  ",data_frame.shape[0]-initial)
    print(data_frame.isnull().sum())
    print("\n\nThe shape of the data_set after removing the null values : ",data_frame.shape)
    return data_frame

# %%
data_frame=CountAndRemoveNullValues(data_frame)
# Out:
# The shape of the data_set before removing the null_values :  (9977, 13)
#
#
# The no. of rows having Null values :   0
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64
#
#
# The shape of the data_set after removing the null values :  (9977, 13)

# %% [markdown]
# #### Visualizing the Data : Correlation Matrix / Heat Map

# %%
#plotting the Heatmap
def PlotHeatMAp(data_frame):
    plt.figure(num=None,figsize=(12,10),dpi=80,facecolor='black',edgecolor='k')
    seaborn.heatmap(data_frame.corr(),annot=True)
    plt.title("\nCorrelation Matrix of all Numerical the features in SampleSuperstore Dataset : \n")
    plt.figure(figsize=(10,10))
    plt.show()

# %%
PlotHeatMAp(data_frame)

# %% [markdown]
# #### Visualizing Each Numeric feature against other Numeric Features in the Dataset

# %%
#Getting the new Data Set HAving only numeric(float/integer) datatypes
Numeric_data_set=data_frame.select_dtypes(include=['float','int'])
print("\nThe Columns/Features with Numeric Data :\n")
Numeric_data_set
# Out:
# The Columns/Features with Numeric Data :
#       Postal Code     Sales  Quantity  Discount    Profit
# 0           42420  261.9600         2      0.00   41.9136
# 1           42420  731.9400         3      0.00  219.5820
# 2           90036   14.6200         2      0.00    6.8714
# 3           33311  957.5775         5      0.45 -383.0310
# 4           33311   22.3680         2      0.20    2.5164
# ...           ...       ...       ...       ...       ...
# 9989        33180   25.2480         3      0.20    4.1028
# 9990        92627   91.9600         2      0.00   15.6332
# 9991        92627  258.5760         2      0.20   19.3932
# 9992        92627   29.6000         4      0.00   13.3200
# 9993        92683  243.1600         2      0.00   72.9480
#
# [9977 rows x 5 columns]

# %% [markdown]
# #### CHECKING  STATISTICAL VALUES OF THE PROFIT AND VERSUS OTHER FACTORS

# %%
#Segment-wise Sales and Profit
segment_sales_and_profit=round(data_frame.groupby("Segment").sum())
segment_sales_and_profit.loc[:,['Sales','Profit']]
# Out:
#                  Sales    Profit
# Segment
# Consumer     1160833.0  134007.0
# Corporate     706070.0   91955.0
# Home Office   429293.0   60279.0

# %%
#shipment-mode wise Sales and Profit
ship_mode_sales_and_profit=round(data_frame.groupby("Ship Mode").sum())
ship_mode_sales_and_profit.loc[:,['Sales','Profit']]
# Out:
#                     Sales    Profit
# Ship Mode
# First Class      351380.0   48954.0
# Same Day         128322.0   15872.0
# Second Class     459177.0   57447.0
# Standard Class  1357316.0  163969.0

# %%
#Country-wise Sales and Profit
country_wise_sales_and_profit=round(data_frame.groupby("Country").sum())
country_wise_sales_and_profit.loc[:,['Sales','Profit']]
# Out:
#                    Sales    Profit
# Country
# United States  2296196.0  286241.0

# %%
#City-wise Sales and Profit
city_wise_sales_and_profit=round(data_frame.groupby("City").sum())
city_wise_sales_and_profit.loc[:,['Sales','Profit']]
# Out:
#               Sales  Profit
# City
# Aberdeen       26.0     7.0
# Abilene         1.0    -4.0
# Akron        2730.0  -187.0
# Albuquerque  2220.0   634.0
# Alexandria   5520.0   319.0
# ...             ...     ...
# Woonsocket    196.0    79.0
# Yonkers      7658.0  2768.0
# York          818.0  -102.0
# Yucaipa        51.0    13.0
# Yuma          841.0  -466.0
#
# [531 rows x 2 columns]

# %%
#State-wise Sales and Profit
state_wise_sales_and_profit=round(data_frame.groupby("State").sum())
state_wise_sales_and_profit.loc[:,['Sales','Profit']]
# Out:
#                          Sales   Profit
# State
# Alabama                19511.0   5787.0
# Arizona                35282.0  -3428.0
# Arkansas               11678.0   4009.0
# California            457576.0  76331.0
# Colorado               32108.0  -6528.0
# Connecticut            13384.0   3511.0
# Delaware               27451.0   9977.0
# District of Columbia    2865.0   1060.0
# Florida                89474.0  -3399.0
# Georgia                49096.0  16250.0
# Idaho                   4382.0    827.0
# Illinois               80163.0 -12602.0
# Indiana                53555.0  18383.0
# Iowa                    4580.0   1184.0
# Kansas                  2914.0    836.0
# Kentucky               36592.0  11200.0
# Louisiana               9217.0   2196.0
# Maine                   1271.0    454.0
# Maryland               23706.0   7031.0
# Massachusetts          28634.0   6786.0
# Michigan               75880.0  24428.0
# Minnesota              29863.0  10823.0
# Mississippi            10771.0   3173.0
# Missouri               22205.0   6436.0
# Montana                 5589.0   1833.0
# Nebraska                7465.0   2037.0
# Nevada                 16729.0   3317.0
# New Hampshire           7293.0   1707.0
# New Jersey             35764.0   9773.0
# New Mexico              4784.0   1157.0
# New York              310827.0  74015.0
# North Carolina         55603.0  -7491.0
# North Dakota             920.0    230.0
# Ohio                   77977.0 -16959.0
# Oklahoma               19683.0   4854.0
# Oregon                 17421.0  -1194.0
# Pennsylvania          116496.0 -15565.0
# Rhode Island           22628.0   7286.0
# South Carolina          8482.0   1769.0
# South Dakota            1316.0    395.0
# Tennessee              30662.0  -5342.0
# Texas                 170125.0 -25751.0
# Utah                   11220.0   2547.0
# Vermont                 8929.0   2245.0
# Virginia               70637.0  18598.0
# Washington            138561.0  33368.0
# West Virginia           1210.0    186.0
# Wisconsin              32115.0   8402.0
# Wyoming                 1603.0    100.0

# %%
#Postal-Code-wise Sales and Profit
Postal_wise_sales_and_profit=round(data_frame.groupby("Postal Code").sum())
Postal_wise_sales_and_profit.loc[:,['Sales','Profit']]
# Out:
#               Sales  Profit
# Postal Code
# 1040          302.0    60.0
# 1453          217.0    80.0
# 1752          207.0    68.0
# 1810          436.0   124.0
# 1841         6109.0  1849.0
# ...             ...     ...
# 98502        1020.0   140.0
# 98632         119.0    39.0
# 98661         687.0    75.0
# 99207        2028.0   172.0
# 99301        2201.0   358.0
#
# [631 rows x 2 columns]

# %%
#Region-wise Sales and Profit
Region_wise_sales_and_profit=round(data_frame.groupby("Region").sum())
Region_wise_sales_and_profit.loc[:,['Sales','Profit']]
# Out:
#             Sales    Profit
# Region
# Central  500783.0   39656.0
# East     678435.0   91506.0
# South    391722.0   46749.0
# West     725256.0  108330.0

# %%
#Category-wise Sales and Profit
Category_wise_sales_and_profit=round(data_frame.groupby("Category").sum())
Category_wise_sales_and_profit.loc[:,['Sales','Profit']]
# Out:
#                     Sales    Profit
# Category
# Furniture        741306.0   18422.0
# Office Supplies  718735.0  122365.0
# Technology       836154.0  145455.0

# %%
#Sub-Category-wise Sales and Profit
Sub_Category_wise_sales_and_profit=round(data_frame.groupby("Sub-Category").sum())
Sub_Category_wise_sales_and_profit.loc[:,['Sales','Profit']]
# Out:
#                  Sales   Profit
# Sub-Category
# Accessories   167380.0  41937.0
# Appliances    107532.0  18138.0
# Art            27107.0   6525.0
# Binders       203409.0  30228.0
# Bookcases     114880.0  -3473.0
# Chairs        327778.0  26567.0
# Copiers       149528.0  55618.0
# Envelopes      16476.0   6964.0
# Fasteners       3024.0    950.0
# Furnishings    91683.0  13053.0
# Labels         12445.0   5526.0
# Machines      189239.0   3385.0
# Paper          78224.0  33944.0
# Phones        330007.0  44516.0
# Storage       223844.0  21279.0
# Supplies       46674.0  -1189.0
# Tables        206966.0 -17725.0

# %%
#Discount-wise Sales and Profit
Discount_wise_sales_and_profit=round(data_frame.groupby("Discount").sum())
Discount_wise_sales_and_profit.loc[:,['Sales','Profit']]
# Out:
#               Sales    Profit
# Discount
# 0.00      1087278.0  320844.0
# 0.10        54369.0    9029.0
# 0.15        27559.0    1419.0
# 0.20       764505.0   90307.0
# 0.30       102945.0  -10357.0
# 0.32        14493.0   -2391.0
# 0.40       116418.0  -23057.0
# 0.45         5485.0   -2493.0
# 0.50        58919.0  -20506.0
# 0.60         6645.0   -5945.0
# 0.70        40620.0  -40075.0
# 0.80        16960.0  -30533.0

# %%
def Plot_Feature1_Versus_Feature2(data_frame):
    # For the Numerical Features
    for feature1 in data_frame.columns:
        for feature2 in data_frame.columns:
            if(feature1!=feature2):
                rand_col=random.choice(['red','blue','green','pink','yellow'])
                plt.figure(num=None, figsize=(10, 10), dpi=80, facecolor='black', edgecolor='k')
                plt.plot(data_frame[feature1].values,data_frame[feature2].values,c=rand_col)
                plt.xlabel=feature1
                plt.ylabel=feature2
                plt.title("{} V/S {} ".format(feature1,feature2))
                plt.show()

# %%
Plot_Feature1_Versus_Feature2(data_frame)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
def Bar_Plots_For_Features(data_frame):
    # For the Numerical Features
    for feature in data_frame.columns:
        plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='black', edgecolor='k')
        seaborn.countplot(x=feature,data=data_frame,palette='Accent')
        plt.xlabel=feature
        plt.ylabel="Count of {}".format(feature)
        plt.title("{} V/S Count of {} ".format(feature,feature))
        plt.show()

# %%
Bar_Plots_For_Features(data_frame)

# %%
def Pie_Plots_For_Features(data_frame):
    # For the Numerical Features
    import matplotlib.pyplot as plt
    for feature in data_frame.columns:
        if feature not in ['Profit','Sales','Postal Code']:
            plt.figure(num=None, figsize=(15,15), dpi=80, facecolor='black', edgecolor='k',)
            data_frame[feature].value_counts().plot.pie(autopct='%5f')
            plt.title("{} Pie Chart".format(feature))
            plt.show()

# %%
Pie_Plots_For_Features(data_frame)

# %% [markdown]
# #### STATES AND CITIES WITH TOP SALES AND PROFITS

# %% [markdown]
# ##### Top 10 States By Sales

# %%
state_wise_sales_and_profit=state_wise_sales_and_profit.loc[:,['Sales','Profit']]
top_10_sales=state_wise_sales_and_profit['Sales'].sort_values(ascending=False).iloc[:10]
print("\n",top_10_sales,"\n\n")
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='black', edgecolor='k')
top_10_sales.plot(kind='bar',color='blue')
plt.xlabel='States'
plt.ylabel='Sales per State'
plt.title("Top 10 States By Sales")
plt.show()
# Out:
#  State
# California      457576.0
# New York        310827.0
# Texas           170125.0
# Washington      138561.0
# Pennsylvania    116496.0
# Florida          89474.0
# Illinois         80163.0
# Ohio             77977.0
# Michigan         75880.0
# Virginia         70637.0
# Name: Sales, dtype: float64

# %% [markdown]
# ##### Top 10 States By Profit

# %%
top_10_profit=state_wise_sales_and_profit['Profit'].sort_values(ascending=False).iloc[:10]
print("\n",top_10_profit,"\n\n")
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='black', edgecolor='k')
top_10_profit.plot(kind='bar',color='blue')
plt.xlabel='States'
plt.ylabel='Profits per State'
plt.title("Top 10 States By Profit")
plt.show()
# Out:
#  State
# California    76331.0
# New York      74015.0
# Washington    33368.0
# Michigan      24428.0
# Virginia      18598.0
# Indiana       18383.0
# Georgia       16250.0
# Kentucky      11200.0
# Minnesota     10823.0
# Delaware       9977.0
# Name: Profit, dtype: float64

# %% [markdown]
# ##### Bottom 10 States By Sales

# %%
state_wise_sales_and_profit=state_wise_sales_and_profit.loc[:,['Sales','Profit']]
bottom_10_sales=state_wise_sales_and_profit['Sales'].sort_values(ascending=True).iloc[:10]
print("\n",bottom_10_sales,"\n\n")
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='black', edgecolor='k')
bottom_10_sales.plot(kind='bar',color='red')
plt.xlabel='States'
plt.ylabel='Sales per State'
plt.title("Bottom 10 States By Sales")
plt.show()
# Out:
#  State
# North Dakota             920.0
# West Virginia           1210.0
# Maine                   1271.0
# South Dakota            1316.0
# Wyoming                 1603.0
# District of Columbia    2865.0
# Kansas                  2914.0
# Idaho                   4382.0
# Iowa                    4580.0
# New Mexico              4784.0
# Name: Sales, dtype: float64

# %% [markdown]
# ##### Bottom 10  States By Profit

# %%
bottom_10_profit=state_wise_sales_and_profit['Profit'].sort_values(ascending=True).iloc[:10]
print("\n",bottom_10_profit,"\n\n")
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='black', edgecolor='k')
bottom_10_profit.plot(kind='bar',color='red')
plt.xlabel='States'
plt.ylabel='Profits per State'
plt.title("Bottom 10 States By Profit")
plt.show()
# Out:
#  State
# Texas            -25751.0
# Ohio             -16959.0
# Pennsylvania     -15565.0
# Illinois         -12602.0
# North Carolina    -7491.0
# Colorado          -6528.0
# Tennessee         -5342.0
# Arizona           -3428.0
# Florida           -3399.0
# Oregon            -1194.0
# Name: Profit, dtype: float64

# %% [markdown]
# ##### Top 10 Cities By Sales

# %%
city_wise_sales_and_profit=city_wise_sales_and_profit.loc[:,['Sales','Profit']]
top_10_sales1=city_wise_sales_and_profit['Sales'].sort_values(ascending=False).iloc[:10]
print("\n",top_10_sales1,"\n\n")
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='black', edgecolor='k')
top_10_sales1.plot(kind='bar',color='blue')
plt.xlabel='Cities'
plt.ylabel='Sales per City'
plt.title("Top 10 Cities By Sales")
plt.show()
# Out:
#  City
# New York City    256319.0
# Los Angeles      175832.0
# Seattle          119460.0
# San Francisco    112577.0
# Philadelphia     109061.0
# Houston           64441.0
# Chicago           48536.0
# San Diego         47521.0
# Jacksonville      44713.0
# Springfield       43054.0
# Name: Sales, dtype: float64

# %% [markdown]
# ##### Top 10 Cities By Profit

# %%
top_10_profit1=city_wise_sales_and_profit['Profit'].sort_values(ascending=False).iloc[:10]
print("\n",top_10_profit1,"\n\n")
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='black', edgecolor='k')
top_10_profit1.plot(kind='bar',color='blue')
plt.xlabel='Cities'
plt.ylabel='Profits per City'
plt.title("Top 10 Cities By Profit")
plt.show()
# Out:
#  City
# New York City    62014.0
# Los Angeles      30431.0
# Seattle          29122.0
# San Francisco    17466.0
# Detroit          13147.0
# Lafayette        10018.0
# Jackson           7582.0
# Atlanta           6994.0
# Minneapolis       6825.0
# San Diego         6377.0
# Name: Profit, dtype: float64

# %% [markdown]
# ##### Bottom 10 Cities By Sales

# %%
city_wise_sales_and_profit=city_wise_sales_and_profit.loc[:,['Sales','Profit']]
bottom_10_sales1=city_wise_sales_and_profit['Sales'].sort_values(ascending=True).iloc[:10]
print("\n",bottom_10_sales1,"\n\n")
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='black', edgecolor='k')
bottom_10_sales1.plot(kind='bar',color='red')
plt.xlabel='Cities'
plt.ylabel='Sales per City'
plt.title("Bottom 10 Cities By Sales")
plt.show()
# Out:
#  City
# Abilene            1.0
# Jupiter            2.0
# Pensacola          2.0
# Elyria             2.0
# Ormond Beach       3.0
# Springdale         4.0
# San Luis Obispo    4.0
# Layton             5.0
# Keller             6.0
# Missouri City      6.0
# Name: Sales, dtype: float64

# %% [markdown]
# ##### Bottom 10  Cities By Profit

# %%
bottom_10_profit1=city_wise_sales_and_profit['Profit'].sort_values(ascending=True).iloc[:10]
print("\n",bottom_10_profit1,"\n\n")
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='black', edgecolor='k')
bottom_10_profit1.plot(kind='bar',color='red')
plt.xlabel='Cities'
plt.ylabel='Profits per City'
plt.title("Bottom 10 Cities By Profit")
plt.show()
# Out:
#  City
# Philadelphia   -13843.0
# Houston        -10175.0
# San Antonio     -7299.0
# Lancaster       -7239.0
# Chicago         -6648.0
# Burlington      -3623.0
# Dallas          -2847.0
# Phoenix         -2791.0
# Aurora          -2692.0
# Jacksonville    -2324.0
# Name: Profit, dtype: float64

# %% [markdown]
# #### CATEGORIES AND SUB-CATEGORIES OF MATERIALS LEADING TO LOSS

# %% [markdown]
# ##### Categories with Corresponding Profit

# %%
Category_wise_sales_and_profit=Category_wise_sales_and_profit.loc[:,['Sales','Profit']]
profit_cat=Category_wise_sales_and_profit['Profit'].sort_values(ascending=False).iloc[:10]
print("\n",profit_cat,"\n\n")
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='black', edgecolor='k')
profit_cat.plot(kind='bar',color='yellow')
plt.xlabel='Categories'
plt.ylabel='Profits per Category'
plt.title("Categories with Corresponding Profit")
plt.show()
# Out:
#  Category
# Technology         145455.0
# Office Supplies    122365.0
# Furniture           18422.0
# Name: Profit, dtype: float64

# %% [markdown]
# ##### Top 5 Sub-Categories with Highest Profit

# %%
Sub_Category_wise_sales_and_profit=Sub_Category_wise_sales_and_profit.loc[:,['Sales','Profit']]
top_5_profit_sub_cat=Sub_Category_wise_sales_and_profit['Profit'].sort_values(ascending=False).iloc[:5]
print("\n",top_5_profit_sub_cat,"\n\n")
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='black', edgecolor='k')
top_5_profit_sub_cat.plot(kind='bar',color='yellow')
plt.xlabel='Sub-Categories'
plt.ylabel='Profits per Sub-Category'
plt.title("Top 5 Sub-Categories with Highest Profit")
plt.show()
# Out:
#  Sub-Category
# Copiers        55618.0
# Phones         44516.0
# Accessories    41937.0
# Paper          33944.0
# Binders        30228.0
# Name: Profit, dtype: float64

# %% [markdown]
# ##### Bottom 5 Sub-Categories with Least Profit

# %%
Sub_Category_wise_sales_and_profit.loc[:,['Sales','Profit']]
bottom_5_profit_sub_cat=Sub_Category_wise_sales_and_profit['Profit'].sort_values(ascending=True).iloc[:5]
print("\n",bottom_5_profit_sub_cat,"\n\n")
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='black', edgecolor='k')
bottom_5_profit_sub_cat.plot(kind='bar',color='red')
plt.xlabel='Sub-Categories'
plt.ylabel='Profits per Sub-Category'
plt.title("Top 5 Sub-Categories with Highest Profit")
plt.show()
# Out:
#  Sub-Category
# Tables      -17725.0
# Bookcases    -3473.0
# Supplies     -1189.0
# Fasteners      950.0
# Machines      3385.0
# Name: Profit, dtype: float64

# %% [markdown]
# ### VISUALIZATION OF MAP OF U.S.A. WITH RESPECT TO PROFIT AND SALES

# %%
# Assigning State Codes to the corressponding states

usa_map_state_codes={'District of Columbia' : 'dc','Mississippi': 'MS', 'Oklahoma': 'OK', 'Delaware': 'DE', 'Minnesota': 'MN',
    'Illinois': 'IL', 'Arkansas': 'AR', 'New Mexico': 'NM', 'Indiana': 'IN', 'Maryland': 'MD', 'Louisiana': 'LA', 
    'Idaho': 'ID', 'Wyoming': 'WY', 'Tennessee': 'TN', 'Arizona': 'AZ', 
    'Iowa': 'IA', 'Michigan': 'MI', 'Kansas': 'KS', 'Utah': 'UT', 
    'Virginia': 'VA', 'Oregon': 'OR', 'Connecticut': 'CT', 'Montana': 'MT', 
    'California': 'CA', 'Massachusetts': 'MA', 'West Virginia': 'WV', 
    'South Carolina': 'SC', 'New Hampshire': 'NH', 'Wisconsin': 'WI',
    'Vermont': 'VT', 'Georgia': 'GA', 'North Dakota': 'ND', 
    'Pennsylvania': 'PA', 'Florida': 'FL', 'Alaska': 'AK', 'Kentucky': 'KY', 
    'Hawaii': 'HI', 'Nebraska': 'NE', 'Missouri': 'MO', 'Ohio': 'OH', 
    'Alabama': 'AL', 'Rhode Island': 'RI', 'South Dakota': 'SD', 
    'Colorado': 'CO', 'New Jersey': 'NJ', 'Washington': 'WA', 
    'North Carolina': 'NC', 'New York': 'NY', 'Texas': 'TX', 
    'Nevada': 'NV', 'Maine': 'ME'}

# %%
# Adding a Column to out Super Market Datasetfor the Corressponding States already Present in the Dataset
data_frame['State-Code']=pd.DataFrame(data_frame['State'].apply(lambda x:usa_map_state_codes[x]))

# %%
data_frame  #new column State-Code is Added
# Out:
#            Ship Mode    Segment        Country  ... Discount    Profit  State-Code
# 0       Second Class   Consumer  United States  ...     0.00   41.9136          KY
# 1       Second Class   Consumer  United States  ...     0.00  219.5820          KY
# 2       Second Class  Corporate  United States  ...     0.00    6.8714          CA
# 3     Standard Class   Consumer  United States  ...     0.45 -383.0310          FL
# 4     Standard Class   Consumer  United States  ...     0.20    2.5164          FL
# ...              ...        ...            ...  ...      ...       ...         ...
# 9989    Second Class   Consumer  United States  ...     0.20    4.1028          FL
# 9990  Standard Class   Consumer  United States  ...     0.00   15.6332          CA
# 9991  Standard Class   Consumer  United States  ...     0.20   19.3932          CA
# 9992  Standard Class   Consumer  United States  ...     0.00   13.3200          CA
# 9993    Second Class   Consumer  United States  ...     0.00   72.9480          CA
#
# [9977 rows x 14 columns]

# %%
#initiating the plotly notebook mode
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#plotly.graph_objects.Figure([data, layout, frames, skip_invalid])
data_frame_map_sales=dict(
    type = 'choropleth',#using chloropleth Maps
    locations = data_frame['State-Code'],
    locationmode = 'USA-states',
    colorscale='Viridis',
    z = data_frame['Sales'],
    colorbar={'title':'Sales by State'}
)
layout=dict(geo={'scope':'usa'})
usa_map=go.Figure([data_frame_map_sales],layout)
iplot(usa_map)
# Out:
# <div>
#
#
#             <div id="88fd0ae3-2be5-4a9e-9dcc-d9ddeb8ef64a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("88fd0ae3-2be5-4a9e-9dcc-d9ddeb8ef64a")) {
#                     Plotly.newPlot(
#                         '88fd0ae3-2be5-4a9e-9dcc-d9ddeb8ef64a',
#                         [{"colorbar": {"title": {"text": "Sales by State"}}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "locationmode": "USA-states", "locations": ["KY", "KY", "CA", "FL", "FL", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "NC", "WA", "TX", "TX", "WI", "UT", "CA", "CA", "CA", "NE", "NE", "PA", "UT", "CA", "CA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "TX", "TX", "TX", "TX", "TX", "TX", "TX", "IL", "CA", "FL", "MN", "MN", "MI", "DE", "DE", "IN", "IN", "IN", "IN", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "CA", "CA", "CA", "CA", "IL", "AZ", "AZ", "VA", "NY", "MI", "TN", "TN", "TN", "TX", "TX", "TX", "TX", "AL", "AL", "CA", "CA", "NC", "IL", "SC", "MN", "MN", "TX", "CA", "CA", "CA", "MN", "MN", "MN", "OR", "NY", "CA", "MN", "IL", "IL", "IL", "MN", "CO", "CO", "CO", "NC", "NC", "NC", "IL", "NY", "IA", "IA", "OH", "OH", "OH", "OH", "WA", "TN", "DE", "DE", "DE", "DE", "DE", "TX", "IL", "AZ", "AZ", "CA", "CA", "OH", "OH", "OH", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "PA", "CA", "CA", "CA", "MO", "CA", "OH", "WI", "WI", "WI", "WI", "AZ", "AZ", "CA", "CA", "CA", "WA", "WA", "OK", "OK", "CA", "PA", "NM", "WA", "TX", "TX", "TX", "TX", "TX", "TX", "TX", "CA", "CA", "CA", "IL", "IL", "TX", "OH", "OH", "NY", "IL", "IL", "LA", "LA", "LA", "CT", "CA", "TX", "TX", "NY", "NY", "NY", "NY", "NY", "CA", "OH", "OH", "NJ", "PA", "PA", "OH", "CO", "CO", "TX", "TN", "CA", "MI", "MI", "MI", "MI", "MI", "TX", "OH", "OH", "OH", "OH", "OH", "CA", "CA", "OH", "OH", "OH", "OH", "OH", "OH", "MI", "MI", "MI", "TN", "TN", "NC", "FL", "FL", "FL", "FL", "FL", "CA", "IL", "IL", "IL", "IL", "IL", "IL", "IL", "MN", "MN", "MN", "MN", "MN", "CA", "CA", "CA", "NY", "NY", "IL", "IL", "IL", "IL", "NY", "NY", "NY", "TX", "TX", "TX", "IL", "CA", "NC", "NJ", "OH", "OH", "CA", "CA", "CA", "CA", "CA", "CA", "PA", "PA", "PA", "PA", "TX", "TX", "CA", "OR", "OR", "OR", "FL", "FL", "FL", "OH", "OH", "OH", "OH", "CO", "CO", "CO", "CO", "CO", "NJ", "NJ", "NJ", "NJ", "NJ", "IL", "NY", "MI", "NJ", "NJ", "VA", "CO", "CO", "CO", "CO", "NJ", "FL", "FL", "PA", "NY", "NY", "NY", "NY", "NY", "CA", "CA", "CA", "TN", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "CA", "CA", "CA", "CA", "CA", "UT", "PA", "PA", "PA", "PA", "TX", "CA", "MA", "MA", "MA", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NC", "GA", "GA", "NY", "NY", "NY", "NY", "CA", "CT", "CT", "CT", "CT", "TX", "TX", "AZ", "AZ", "AZ", "AZ", "IL", "MA", "TX", "TX", "TX", "CA", "CA", "MI", "FL", "FL", "PA", "PA", "OH", "NY", "NY", "WA", "WA", "IL", "NV", "RI", "RI", "MI", "TX", "TX", "TX", "TX", "FL", "NC", "NY", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "WA", "WA", "CA", "CA", "KY", "CA", "CA", "CO", "MA", "MA", "MS", "MI", "MI", "NY", "TX", "NC", "NC", "NC", "NC", "MA", "FL", "FL", "IL", "IL", "TX", "NY", "MI", "MI", "MI", "MI", "MI", "MI", "IN", "NY", "NY", "NY", "NY", "NY", "NY", "OH", "OH", "OK", "CA", "IL", "IL", "WA", "WA", "WA", "AZ", "AZ", "AZ", "AZ", "AZ", "IL", "TX", "IL", "NY", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "NY", "NY", "NY", "CA", "NY", "NY", "CA", "CA", "CA", "IL", "TX", "TX", "TX", "NY", "NY", "WA", "TN", "AR", "CA", "CA", "CA", "CA", "CO", "CO", "CO", "CO", "CO", "NY", "GA", "GA", "GA", "GA", "MO", "MO", "OH", "CA", "CA", "MT", "MT", "MT", "MT", "TX", "TX", "TX", "MI", "CA", "CA", "MA", "FL", "FL", "PA", "PA", "PA", "CA", "CA", "AL", "AL", "AZ", "IL", "NY", "KY", "KY", "WI", "AZ", "OH", "TX", "TX", "TX", "NY", "NY", "IL", "IL", "IL", "CA", "FL", "TX", "CA", "NC", "CA", "CA", "CA", "CA", "CA", "FL", "FL", "WA", "WA", "CA", "WA", "WA", "WA", "WA", "NY", "NY", "NY", "NY", "WA", "CA", "CA", "CA", "IL", "IL", "CA", "CO", "CO", "CO", "CO", "CO", "KY", "KY", "OR", "OR", "OR", "OR", "TX", "TX", ...

# %%
#plotly.graph_objects.Figure([data, layout, frames, skip_invalid])
data_frame_map_profit=dict(
    type = 'choropleth',#using chloropleth Maps
    locations = data_frame['State-Code'],
    locationmode = 'USA-states',
    colorscale='Viridis',
    z = data_frame['Profit'],
    colorbar={'title':'Profit by State'}
)
layout=dict(geo={'scope':'usa'})
usa_map=go.Figure([data_frame_map_profit],layout)
iplot(usa_map)
# Out:
# <div>
#
#
#             <div id="206f0d34-ec40-48b7-b1d9-9becd8e600ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("206f0d34-ec40-48b7-b1d9-9becd8e600ed")) {
#                     Plotly.newPlot(
#                         '206f0d34-ec40-48b7-b1d9-9becd8e600ed',
#                         [{"colorbar": {"title": {"text": "Profit by State"}}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "locationmode": "USA-states", "locations": ["KY", "KY", "CA", "FL", "FL", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "NC", "WA", "TX", "TX", "WI", "UT", "CA", "CA", "CA", "NE", "NE", "PA", "UT", "CA", "CA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "TX", "TX", "TX", "TX", "TX", "TX", "TX", "IL", "CA", "FL", "MN", "MN", "MI", "DE", "DE", "IN", "IN", "IN", "IN", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "CA", "CA", "CA", "CA", "IL", "AZ", "AZ", "VA", "NY", "MI", "TN", "TN", "TN", "TX", "TX", "TX", "TX", "AL", "AL", "CA", "CA", "NC", "IL", "SC", "MN", "MN", "TX", "CA", "CA", "CA", "MN", "MN", "MN", "OR", "NY", "CA", "MN", "IL", "IL", "IL", "MN", "CO", "CO", "CO", "NC", "NC", "NC", "IL", "NY", "IA", "IA", "OH", "OH", "OH", "OH", "WA", "TN", "DE", "DE", "DE", "DE", "DE", "TX", "IL", "AZ", "AZ", "CA", "CA", "OH", "OH", "OH", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "PA", "CA", "CA", "CA", "MO", "CA", "OH", "WI", "WI", "WI", "WI", "AZ", "AZ", "CA", "CA", "CA", "WA", "WA", "OK", "OK", "CA", "PA", "NM", "WA", "TX", "TX", "TX", "TX", "TX", "TX", "TX", "CA", "CA", "CA", "IL", "IL", "TX", "OH", "OH", "NY", "IL", "IL", "LA", "LA", "LA", "CT", "CA", "TX", "TX", "NY", "NY", "NY", "NY", "NY", "CA", "OH", "OH", "NJ", "PA", "PA", "OH", "CO", "CO", "TX", "TN", "CA", "MI", "MI", "MI", "MI", "MI", "TX", "OH", "OH", "OH", "OH", "OH", "CA", "CA", "OH", "OH", "OH", "OH", "OH", "OH", "MI", "MI", "MI", "TN", "TN", "NC", "FL", "FL", "FL", "FL", "FL", "CA", "IL", "IL", "IL", "IL", "IL", "IL", "IL", "MN", "MN", "MN", "MN", "MN", "CA", "CA", "CA", "NY", "NY", "IL", "IL", "IL", "IL", "NY", "NY", "NY", "TX", "TX", "TX", "IL", "CA", "NC", "NJ", "OH", "OH", "CA", "CA", "CA", "CA", "CA", "CA", "PA", "PA", "PA", "PA", "TX", "TX", "CA", "OR", "OR", "OR", "FL", "FL", "FL", "OH", "OH", "OH", "OH", "CO", "CO", "CO", "CO", "CO", "NJ", "NJ", "NJ", "NJ", "NJ", "IL", "NY", "MI", "NJ", "NJ", "VA", "CO", "CO", "CO", "CO", "NJ", "FL", "FL", "PA", "NY", "NY", "NY", "NY", "NY", "CA", "CA", "CA", "TN", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "CA", "CA", "CA", "CA", "CA", "UT", "PA", "PA", "PA", "PA", "TX", "CA", "MA", "MA", "MA", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NC", "GA", "GA", "NY", "NY", "NY", "NY", "CA", "CT", "CT", "CT", "CT", "TX", "TX", "AZ", "AZ", "AZ", "AZ", "IL", "MA", "TX", "TX", "TX", "CA", "CA", "MI", "FL", "FL", "PA", "PA", "OH", "NY", "NY", "WA", "WA", "IL", "NV", "RI", "RI", "MI", "TX", "TX", "TX", "TX", "FL", "NC", "NY", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "WA", "WA", "CA", "CA", "KY", "CA", "CA", "CO", "MA", "MA", "MS", "MI", "MI", "NY", "TX", "NC", "NC", "NC", "NC", "MA", "FL", "FL", "IL", "IL", "TX", "NY", "MI", "MI", "MI", "MI", "MI", "MI", "IN", "NY", "NY", "NY", "NY", "NY", "NY", "OH", "OH", "OK", "CA", "IL", "IL", "WA", "WA", "WA", "AZ", "AZ", "AZ", "AZ", "AZ", "IL", "TX", "IL", "NY", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "NY", "NY", "NY", "CA", "NY", "NY", "CA", "CA", "CA", "IL", "TX", "TX", "TX", "NY", "NY", "WA", "TN", "AR", "CA", "CA", "CA", "CA", "CO", "CO", "CO", "CO", "CO", "NY", "GA", "GA", "GA", "GA", "MO", "MO", "OH", "CA", "CA", "MT", "MT", "MT", "MT", "TX", "TX", "TX", "MI", "CA", "CA", "MA", "FL", "FL", "PA", "PA", "PA", "CA", "CA", "AL", "AL", "AZ", "IL", "NY", "KY", "KY", "WI", "AZ", "OH", "TX", "TX", "TX", "NY", "NY", "IL", "IL", "IL", "CA", "FL", "TX", "CA", "NC", "CA", "CA", "CA", "CA", "CA", "FL", "FL", "WA", "WA", "CA", "WA", "WA", "WA", "WA", "NY", "NY", "NY", "NY", "WA", "CA", "CA", "CA", "IL", "IL", "CA", "CO", "CO", "CO", "CO", "CO", "KY", "KY", "OR", "OR", "OR", "OR", "TX", "TX" ...
